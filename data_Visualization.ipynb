# %% [markdown]
# **Sebelum menelaah data dengan metode visualisasi, kita perlu memanggil modul visualisasi (seaborn & matplotlib) terlebih dahulu.**

# %%
# memanggil modul pandas dan seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight') 

import warnings
warnings.filterwarnings('ignore')

# %%
#membaca file ke dalam pandas
bunga ='Iris.csv'
df = pd.read_csv(bunga)

# %%
#menampilkan 5 baris data teratas
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Karena kita tidak membutuhkan kolom "Id" dalam melakukan visualisasi kita dapat menghapus kolom "Id" menggunakan fungsi .drop()**

# %%
df.drop('Id', inplace=True, axis=1) #kolom Id sudah terhapus, jika ini di run lagi, error
print(df)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Pengecekan nilai yang hilang (missing value) pada dataset. Dengan function info()**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # **Menampilkan visualisasi dari data yang telah menggunakan fungsi describe() untuk mendapatkan informasi umum statistik tentang dataset**

# %%
# melakukan visualisasi dari data describe
df.describe().plot(kind = "area", figsize = (6.4, 4.8), colormap="viridis")
plt.xlabel('Statistics',fontsize=14)
plt.show('Value')
plt.title("General Statistics of Iris Dataset",fontsize=18)
# Out:
# Text(0.5, 1.0, 'General Statistics of Iris Dataset')

# %% [markdown]
# **Menampilkan visualisasi bar plot dan pie chart untuk menghitung frekuensi setiap species dalam dataset iris**

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Iris Species Count')
ax[0].set_title('Count')
sns.kind="bar"('Species',data=df,ax=ax[1])
ax[1].set_title('Iris Species Count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-274ca22e27b8> in <module>()
#       3 ax[0].set_title('Iris Species Count')
#       4 ax[0].set_title('Count')
# ----> 5 sns.kind="bar"('Species',data=df,ax=ax[1])
#       6 ax[1].set_title('Iris Species Count')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Plot Residual

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind="residplot", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-e910a6bf72cb> in <module>()
# ----> 1 sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind="residplot", data=df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2205     # Validate the plot kind
#    2206     plot_kinds = ["scatter", "hist", "hex", "kde", "reg", "resid"]
# -> 2207     _check_argument("kind", plot_kinds, kind)
#    2208
#    2209     # Raise early if using `hue` with a kind that does not support it
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in _check_argument(param, options, value)
#     784     if value not in options:
#     785         raise ValueError(
# --> 786             f"`{param}` must be one of {options}, but {value} was passed.`"
#     787         )
#     788
#
# ValueError: `kind` must be one of ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid'], but residplot was passed.`

# %% [markdown]
# Scatter plot

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind="scatter", data=df)

# %% [markdown]
# Hexagons plot

# %%
sns.jointplot('SepalLengthCm','SepalWidthCm',kind="hex",data=df)

# %% [markdown]
# Linear regression line plot

# %%
sns.jointplot('SepalLengthCm','SepalWidthCm', data=df, kind="residplot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-ab3734719816> in <module>()
# ----> 1 sns.jointplot('SepalLengthCm','SepalWidthCm', data=df, kind="residplot")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2205     # Validate the plot kind
#    2206     plot_kinds = ["scatter", "hist", "hex", "kde", "reg", "resid"]
# -> 2207     _check_argument("kind", plot_kinds, kind)
#    2208
#    2209     # Raise early if using `hue` with a kind that does not support it
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in _check_argument(param, options, value)
#     784     if value not in options:
#     785         raise ValueError(
# --> 786             f"`{param}` must be one of {options}, but {value} was passed.`"
#     787         )
#     788
#
# ValueError: `kind` must be one of ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid'], but residplot was passed.`

# %% [markdown]
#  Kernel density estimate plot

# %%
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=df, kind="kde",color='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-b66bf384f26b> in <module>()
# ----> 1 sns.jointplot("SepalLengthCm", "SepalWidthCm", data=df, kind="kde",color='b')
#
# NameError: name 'sns' is not defined

# %% [markdown]
#  Penggabungan plot

# %%
sns.miscplot("SepalLengthCm", "SepalWidthCm",data=df, color="b").plt.subplots(sns.kdeplot, zorder=0, n_levels=6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-e5b335cd979f> in <module>()
# ----> 1 sns.miscplot("SepalLengthCm", "SepalWidthCm",data=df, color="b").plt.subplots(sns.kdeplot, zorder=0, n_levels=6)
#
# TypeError: 'module' object is not callable

# %% [markdown]
# Visualisasi Boxplot untuk memberikan ringkasan statis dari fitur yang diplot.
#
# Garis atas mewakili nilai maksimal
# Tepi atas kotak adalah Kuartil ketiga
# Tepi tengah adalah median,
# Tepi bawah adalah nilai kuartil pertama.
# Garis paling bawah adalah nilai minimum.
# Ketinggian kotak disebut sebagai rentang Interkuartil.
# Titik-titik hitam pada plot adalah nilai outlier dalam data.
# Menampilkan visualisasi boxplot menggunakan kolom "Species" dan "PetalLengthCm" dalam dataset iris

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='PetalLengthCm',data=df,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)

# %%
# visualisasi Boxplot yang di kelompokkan berdasarkan "Species"
plt.box(by="Species", figsize=(12, 6))
pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-84f1cdf7113b> in <module>()
#       1 # visualisasi Boxplot yang di kelompokkan berdasarkan "Species"
# ----> 2 plt.box(by="Species", figsize=(12, 6))
#       3 pass
#
# TypeError: box() got an unexpected keyword argument 'by'

# %% [markdown]
# Visualisasi Violin Plot untuk memvisualisasikan sebaran data dan distribusi probabilitas.
#
# Bilah hitam tebal di tengah mewakili rentang interkuartil
# Garis hitam tipis yang memanjang darinya mewakili interval kepercayaan 95%
# Titik putih adalah median.
# Menampilkan visualisasi Violin Plot dengan menggunakan setiap kolom yang ada untuk melihat sebaran data terhadap kolom "Species" dalam dataset iris

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=df)
plt.subplot
sns.violinplot(x='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=df)

# %% [markdown]
# Visualisasi pairplot yang juga dikenal dengan scatterplot adalah visualisasi sebaran data yang menunjukan keterkaitan antar kolom.
#
# Menampilkan visualisasi pairplot dari setiap kolom yang ada untuk melihat sebaran data dalam dataset iris

# %%
sns.jointplot(data=df,kind='scatter')

# %% [markdown]
# Visualisasi heatmap digunakan untuk mengetahui korelasi setiap kolom dalam dataset. Nilai positif atau negatif yang tinggi menunjukkan bahwa fitur tersebut memiliki korelasi yang tinggi. Hal ini membantu kita memilih parameter untuk machine learning.
#
# Menampilkan visualisasi heatmap dari korelasi setiap fitur dalam dataset iris

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(df.corr(),annot=True,cmap='coolwarm',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %% [markdown]
# Visualisasi Distribution plot untuk membandingkan jangkauan dan distribusi untuk dataset numerik. Visualisasi Distribution plot tidak relevan untuk analisis data yang terperinci karena berkaitan dengan ringkasan distribusi data.
#
# Menampilkan visualisasi Distribution plot setiap fitur dalam dataset iris

# %%
df.plot(linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %% [markdown]
# Visualisasi Residual Plot adalah visualisasi untuk memplot residu dengan nilai prediksi pada sumbu x, dan residu pada sumbu y. Jarak dari garis 0 adalah seberapa buruk prediksi untuk nilai yang di plot.
#
# Menampilkan visualisasi Residual Plot dari fitur "SepalLengthCm" dan SepalWidthCm dalam dataset iris

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.residplot('SepalLengthCm', 'SepalWidthCm',data=df,lowess=True)

# %% [markdown]
# Visualisasi Stacked Histogram digunakan untuk menunjukkan bagaimana fitur yang lebih besar dibagi menjadi fitur yang lebih kecil dan menunjukan hubungan masing-masing fitur terhadap jumlah total
#
# Tampilkan visualisasi Stacked Histogram dari fitur "Species" dengan mengubah tipe datanya menjadi category (astype) dalam dataset iris

# %%
df['Species'] = df['Species'].astype('category')
#df.head()
list1=list()
mylabels=list()
for gen in df.Species.cat.categories:
    list1.append(df[df.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.plot
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Visualisasi Area Plot memberi kita representasi visual dari Berbagai dimensi dalam dataset.
#
# Menampilkan visualisasi Area Plot dari fitur 'SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm' dalam dataset iris

# %%
sns.pointplot(df['SepalLengthCm'],kde=True,bins=20);

# %% [markdown]
# Visualisasi distplot membantu untuk melihat distribusi variabel tunggal. Kde menunjukkan kepadatan distribusi
#
# Tampilkan visualisasi distplot dari fitur 'SepalLengthCm' dengan menggunakan Kde (kind) untuk menunjukkan kepadatan distribusi dalam dataset iris

# %%
sns.distplot(df['SepalLengthCm'],kde=True,bins=20);
